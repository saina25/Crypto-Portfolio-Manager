# %% [markdown]
# <a href="https://colab.research.google.com/github/saina25/Crypto-Portfolio-Manager/blob/main/Python_and_SQL_Tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

topic = input("Enter Python topic: ").strip().lower()

data = {
    "basics": [
        ("What are mutable and immutable objects?",
         "Mutable objects can be changed after creation like lists. Immutable objects cannot be changed like strings and tuples."),
        ("What is dynamic typing?",
         "Dynamic typing means variable types are determined at runtime without explicit declaration."),
        ("Difference between list and tuple?",
         "Lists are mutable and use square brackets. Tuples are immutable and use parentheses."),
        ("What are Python data types?",
         "Common data types include int, float, str, list, tuple, set, and dictionary."),
        ("Why is indentation important?",
         "Indentation defines code blocks instead of braces as used in other languages.")
    ],
    "functions": [
        ("What are *args and **kwargs?",
         "*args allows variable positional arguments, **kwargs allows variable keyword arguments."),
        ("What is recursion?",
         "Recursion is when a function calls itself to solve smaller subproblems."),
        ("What is a lambda function?",
         "A lambda is an anonymous function defined using the lambda keyword."),
        ("What are default arguments?",
         "Default arguments allow parameters to have predefined values if not provided."),
        ("Are functions first-class objects?",
         "Yes, functions can be assigned to variables, passed as arguments and returned from other functions.")
    ],
    "oops": [
        ("What is encapsulation?",
         "Encapsulation restricts direct access to data and methods using private variables."),
        ("Explain inheritance.",
         "Inheritance allows one class to acquire properties and methods of another class."),
        ("What is polymorphism?",
         "Polymorphism allows the same method name to behave differently in different classes."),
        ("What is method overriding?",
         "Method overriding occurs when a child class redefines a method of the parent class."),
        ("What is a constructor?",
         "A constructor is a special method named __init__ that initializes object attributes.")
    ],
    "exceptions": [
        ("What is exception handling?",
         "Exception handling manages runtime errors using try and except blocks."),
        ("What is finally block?",
         "Finally block always executes whether an exception occurs or not."),
        ("How to raise custom exceptions?",
         "Custom exceptions can be raised using the raise keyword."),
        ("Difference between error and exception?",
         "Errors are serious issues, exceptions are manageable runtime problems."),
        ("What is multiple exception handling?",
         "Multiple exceptions can be handled using multiple except blocks.")
    ]
}

if topic in data:
    selected = random.sample(data[topic], len(data[topic]))
    for i, qa in enumerate(selected, 1):
        print(str(i) + ". " + qa[0])
        print("Answer:", qa[1])
        print()
else:
    print("Topic not found.")
    print("Available topics:")
    for t in data:
        print("-", t)
# Out:
# Enter Python topic: oops
# 1. What is method overriding?
# Answer: Method overriding occurs when a child class redefines a method of the parent class.
#
# 2. What is encapsulation?
# Answer: Encapsulation restricts direct access to data and methods using private variables.
#
# 3. What is polymorphism?
# Answer: Polymorphism allows the same method name to behave differently in different classes.
#
# 4. What is a constructor?
# Answer: A constructor is a special method named __init__ that initializes object attributes.
#
# 5. Explain inheritance.
# Answer: Inheritance allows one class to acquire properties and methods of another class.

# %%
import random

topic = input("Enter SQL topic: ").strip().lower()

data = {
    "basics": [
        ("What is SQL?",
         "SQL stands for Structured Query Language and is used to manage and manipulate relational databases."),
        ("What are primary keys?",
         "A primary key uniquely identifies each record in a table and cannot contain NULL values."),
        ("What is a foreign key?",
         "A foreign key is a field that links one table to the primary key of another table."),
        ("What is a NULL value?",
         "NULL represents missing or unknown data in a table."),
        ("Difference between DELETE and DROP?",
         "DELETE removes records from a table, while DROP removes the entire table structure.")
    ],
    "joins": [
        ("What is an INNER JOIN?",
         "INNER JOIN returns only matching records from both tables."),
        ("What is a LEFT JOIN?",
         "LEFT JOIN returns all records from the left table and matching records from the right table."),
        ("What is a RIGHT JOIN?",
         "RIGHT JOIN returns all records from the right table and matching records from the left table."),
        ("What is a FULL JOIN?",
         "FULL JOIN returns all records when there is a match in either left or right table."),
        ("Difference between JOIN and UNION?",
         "JOIN combines columns from multiple tables, UNION combines rows from multiple queries.")
    ],
    "normalization": [
        ("What is normalization?",
         "Normalization organizes data to reduce redundancy and improve data integrity."),
        ("What is 1NF?",
         "First Normal Form ensures all columns contain atomic values."),
        ("What is 2NF?",
         "Second Normal Form removes partial dependency on composite keys."),
        ("What is 3NF?",
         "Third Normal Form removes transitive dependency."),
        ("What is denormalization?",
         "Denormalization combines tables to improve read performance.")
    ],
    "queries": [
        ("How to find second highest salary?",
         "Use ORDER BY salary DESC with LIMIT and OFFSET or a subquery."),
        ("What is a subquery?",
         "A subquery is a query inside another query."),
        ("What is GROUP BY?",
         "GROUP BY groups rows with similar values into summary rows."),
        ("Difference between WHERE and HAVING?",
         "WHERE filters rows before grouping, HAVING filters groups after aggregation."),
        ("What is an index?",
         "An index improves database retrieval speed at the cost of additional storage.")
    ]
}

if topic in data:
    selected = random.sample(data[topic], len(data[topic]))
    for i, qa in enumerate(selected, 1):
        print(str(i) + ". " + qa[0])
        print("Answer:", qa[1])
        print()
else:
    print("Topic not found.")
    print("Available topics:")
    for t in data:
        print("-", t)
# Out:
# Enter SQL topic: joins
# 1. What is an INNER JOIN?
# Answer: INNER JOIN returns only matching records from both tables.
#
# 2. What is a LEFT JOIN?
# Answer: LEFT JOIN returns all records from the left table and matching records from the right table.
#
# 3. What is a FULL JOIN?
# Answer: FULL JOIN returns all records when there is a match in either left or right table.
#
# 4. Difference between JOIN and UNION?
# Answer: JOIN combines columns from multiple tables, UNION combines rows from multiple queries.
#
# 5. What is a RIGHT JOIN?
# Answer: RIGHT JOIN returns all records from the right table and matching records from the left table.
